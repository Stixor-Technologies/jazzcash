# %%
import pandas as pd

# Load the dataset
file_path = "/home/nazar/Muhammad Raees Azam/jazzcash/notebooks/SyntheticProcessed.csv"
df = pd.read_csv(file_path)

# Display structure
print("Columns in Dataset:\n", df.columns.tolist())
print("\n Data Types:\n", df.dtypes)
print("\n First 5 Rows:\n", df.head())
print("\n Summary Statistics:\n", df.describe(include='all'))
# Out:
# Columns in Dataset:
#  ['Type', 'Amount', 'ID Source', 'Old Balance', 'New Balance', 'State Source', 'City Source', 'Device Name', 'IMEI', 'KYC Status', 'Service Charges', 'Channel', 'ID Dest', 'State Dest', 'City Dest', 'Is Fraud', 'year', 'month', 'day', 'hour', 'minute', 'second', 'weekday', 'day_of_year']
#
#  Data Types:
#  Type                 int64
# Amount             float64
# ID Source            int64
# Old Balance        float64
# New Balance        float64
# State Source         int64
# City Source          int64
# Device Name          int64
# IMEI                 int64
# KYC Status           int64
# Service Charges    float64
# Channel              int64
# ID Dest              int64
# State Dest           int64
# City Dest            int64
# Is Fraud             int64
# year                 int64
# month                int64
# day                  int64
# hour                 int64
# minute               int64
# second               int64
# weekday              int64
# day_of_year          int64
# dtype: object
#
#  First 5 Rows:
#     Type    Amount  ID Source  Old Balance  New Balance  State Source  \
# 0     3   9839.64     757869     170136.0    160296.36             0
# 1     3   1864.28    2188998      21249.0     19384.72             0
# 2     4    181.00    1002156        181.0         0.00             6
# 3     1    181.00    5828262        181.0         0.00             5
# 4     3  11668.14    3445981      41554.0     29885.86             4
#
#    City Source  Device Name             IMEI  KYC Status  ...  City Dest  \
# 0           24            3   44411858565857           0  ...         10
# 1            2            4  826450771187914           1  ...         18
# 2           48            1  941610250811953           3  ...         18
# 3           35            1   52286958511926           0  ...         11
# 4           23            4  971425695893177           2  ...         16
#
#    Is Fraud  year  month  day  hour  minute  second  weekday  day_of_year
# 0         0  2024      1   10     0       0      32        2           10
# 1         0  2024      1   10     0       0      39        2           10
# 2         1  2024      1   10     0       0      43        2           10
# 3         1  2019     10   21     5      47      52        0          294
# 4         0  2019     10   21     5      47      55        0          294
#
# [5 rows x 24 columns]
#
#  Summary Statistics:
#                 Type        Amount     ID Source   Old Balance   New Balance  \
# count  6.362620e+06  6.362620e+06  6.362620e+06  6.362620e+06  6.362620e+06
# mean   1.714150e+00  1.798619e+05  3.176678e+06  8.338831e+05  8.551137e+05
# std    1.350117e+00  6.038582e+05  1.834064e+06  2.888243e+06  2.924049e+06
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.000000e+00  1.338957e+04  1.588332e+06  0.000000e+00  0.000000e+00
# 50%    1.000000e+00  7.487194e+04  3.176672e+06  1.420800e+04  0.000000e+00
# 75%    3.000000e+00  2.087215e+05  4.765048e+06  1.073152e+05  1.442584e+05
# max    4.000000e+00  9.244552e+07  6.353306e+06  5.958504e+07  4.958504e+07
#
#        State Source   City Source   Device Name          IMEI    KYC Status  \
# count  6.362620e+06  6.362620e+06  6.362620e+06  6.362620e+06  6.362620e+06
# mean   2.999124e+00  2.350465e+01  2.000208e+00  5.000116e+14  1.501073e+00
# std    2.000222e+00  1.395703e+01  1.414244e+00  2.886274e+14  1.117923e+00
# min    0.000000e+00  0.000000e+00  0.000000e+00  3.732971e+07  0.000000e+00
# 25%    1.000000e+00  1.300000e+01  1.000000e+00  2.500477e+14  1.000000e+00
# 50%    3.000000e+00  2.100000e+01  2.000000e+00  4.998218e+14  2.000000e+00
# 75%    5.000000e+00  3.400000e+01  3.000000e+00  7.500517e+14  3.000000e+00
# max    6.000000e+00  5.000000e+01  4.000000e+00  9.999998e+14  3.000000e+00
#
#        ...     City Dest      Is Fraud          year         month  \
# count  ...  6.362620e+06  6.362620e+06  6.362620e+06  6.362620e+06
# mean   ...  2.350160e+01  1.290820e-03  2.022002e+03  6.502027e+00
# std    ...  1.395527e+01  3.590480e-02  1.998597e+00  3.452542e+00
# min    ...  0.000000e+00  0.000000e+00  2.019000e+03  1.000000e+00
# 25%    ...  1.300000e+01  0.000000e+00  2.020000e+03  4.000000e+00
# 50%    ...  2.100000e+01  0.000000e+00  2.022000e+03  7.000000e+00
# 75%    ...  3.400000e+01  0.000000e+00  2.024000e+03  1.000000e+01
# max    ...  5.000000e+01  1.000000e+00  2.025000e+03  1.200000e+01
#
#                 day          hour        minute        second       weekday  \
# count  6.362620e+06  6.362620e+06  6.362620e+06  6.362620e+06  6.362620e+06
# mean   1.450009e+01  1.148161e+01  2.949198e+01  2.949936e+01  2.996650e+00
# std    8.079726e+00  6.926191e+00  1.731443e+01  1.731852e+01  2.000690e+00
# min    1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    7.000000e+00  5.000000e+00  1.400000e+01  1.400000e+01  1.000000e+00
# 50%    1.400000e+01  1.100000e+01  3.000000e+01  2.900000e+01  3.000000e+00
# 75%    2.200000e+01  1.700000e+01  4.400000e+01  4.500000e+01  5.000000e+00
# max    2.900000e+01  2.300000e+01  5.900000e+01  5.900000e+01  6.000000e+00
#
#         day_of_year
# count  6.362620e+06
# mean   1.813023e+02
# std    1.054132e+02
# min    1.000000e+00
# 25%    9.100000e+01
# 50%    1.820000e+02
# 75%    2.740000e+02
# max    3.630000e+02
#
# [8 rows x 24 columns]

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("/home/nazar/Muhammad Raees Azam/jazzcash/notebooks/SyntheticProcessed.csv")

# Construct datetime from individual components
df['timestamp'] = pd.to_datetime(df[['year', 'month', 'day', 'hour', 'minute', 'second']])
df.sort_values(by=['ID Source', 'timestamp'], inplace=True)  # Sort for future calculations

# %%
#Rule 1: n transactions within m minutes (e.g., 3 txns in 5 minutes)

from collections import deque

n, m = 3, 5  # example: 3 transactions in 5 minutes
flag_rapid_txns = []

for _, group in df.groupby('ID Source'):
    dq = deque()
    group_flags = []
    
    for t in group['timestamp']:
        dq.append(t)
        while (dq[-1] - dq[0]).total_seconds() > m * 60:
            dq.popleft()
        group_flags.append(1 if len(dq) >= n else 0)
    
    flag_rapid_txns.extend(group_flags)

df['flag_rapid_txns'] = flag_rapid_txns

# %%
df
# Out:
#          Type     Amount  ID Source  Old Balance  New Balance  State Source  \
# 3196942     1  244486.46          0      8946.00         0.00             3
# 2798983     3    3170.28          1     58089.00     54918.72             3
# 1013585     3    8424.74          2       783.00         0.00             1
# 2980283     0  261877.19          3      7596.00    269473.19             1
# 1920204     0   20528.65          4   2302074.12   2322602.77             2
# ...       ...        ...        ...          ...          ...           ...
# 5467102     3   26585.43    6353302         0.00         0.00             6
# 323336      0   37516.21    6353303  18820782.28  18858298.49             5
# 768108      1  244962.21    6353304     22027.00         0.00             6
# 2310367     3   15714.59    6353305         0.00         0.00             6
# 2976245     1  275783.53    6353306    126018.02         0.00             3
#
#          City Source  Device Name             IMEI  KYC Status  ...  year  \
# 3196942           18            0  927866134346668           0  ...  2019
# 2798983           18            0  523023208809408           2  ...  2021
# 1013585           50            4  826769516434938           2  ...  2020
# 2980283           37            3  808816955619213           1  ...  2020
# 1920204           13            3   46281521129530           3  ...  2024
# ...              ...          ...              ...         ...  ...   ...
# 5467102           30            1  358722602404200           0  ...  2025
# 323336            25            4  955144871951531           3  ...  2021
# 768108            30            1  270348759515170           3  ...  2020
# 2310367           48            3  376257479668904           3  ...  2025
# 2976245           18            0  710183950720366           2  ...  2021
#
#          month  day  hour  minute  second  weekday  day_of_year  \
# 3196942      9   14    17      14       8        5          257
# 2798983     10   12    12      54      18        1          285
# 1013585      2   19     3      18      31        2           50
# 2980283     12    3     4      11      27        3          338
# 1920204      8   17     1      53      24        5          230
# ...        ...  ...   ...     ...     ...      ...          ...
# 5467102      4    9    16      42      41        2           99
# 323336       6    4    17      18       1        4          155
# 768108       2   19    17      43      10        2           50
# 2310367     12    7    10      18      22        6          341
# 2976245      9   21    15      30      31        1          264
#
#                   timestamp  flag_rapid_txns
# 3196942 2019-09-14 17:14:08                0
# 2798983 2021-10-12 12:54:18                0
# 1013585 2020-02-19 03:18:31                0
# 2980283 2020-12-03 04:11:27                0
# 1920204 2024-08-17 01:53:24                0
# ...                     ...              ...
# 5467102 2025-04-09 16:42:41                0
# 323336  2021-06-04 17:18:01                0
# 768108  2020-02-19 17:43:10                0
# 2310367 2025-12-07 10:18:22                0
# 2976245 2021-09-21 15:30:31                0
#
# [6362620 rows x 26 columns]

# %%
#Rule 2: High-risk cities

# Example: city codes 101, 202 are high-risk
high_risk_cities = [101, 202]

df['flag_high_risk_city'] = df['City Source'].isin(high_risk_cities) | df['City Dest'].isin(high_risk_cities)

# %%
df
# Out:
#          Type     Amount  ID Source  Old Balance  New Balance  State Source  \
# 3196942     1  244486.46          0      8946.00         0.00             3
# 2798983     3    3170.28          1     58089.00     54918.72             3
# 1013585     3    8424.74          2       783.00         0.00             1
# 2980283     0  261877.19          3      7596.00    269473.19             1
# 1920204     0   20528.65          4   2302074.12   2322602.77             2
# ...       ...        ...        ...          ...          ...           ...
# 5467102     3   26585.43    6353302         0.00         0.00             6
# 323336      0   37516.21    6353303  18820782.28  18858298.49             5
# 768108      1  244962.21    6353304     22027.00         0.00             6
# 2310367     3   15714.59    6353305         0.00         0.00             6
# 2976245     1  275783.53    6353306    126018.02         0.00             3
#
#          City Source  Device Name             IMEI  KYC Status  ...  month  \
# 3196942           18            0  927866134346668           0  ...      9
# 2798983           18            0  523023208809408           2  ...     10
# 1013585           50            4  826769516434938           2  ...      2
# 2980283           37            3  808816955619213           1  ...     12
# 1920204           13            3   46281521129530           3  ...      8
# ...              ...          ...              ...         ...  ...    ...
# 5467102           30            1  358722602404200           0  ...      4
# 323336            25            4  955144871951531           3  ...      6
# 768108            30            1  270348759515170           3  ...      2
# 2310367           48            3  376257479668904           3  ...     12
# 2976245           18            0  710183950720366           2  ...      9
#
#          day  hour  minute  second  weekday  day_of_year           timestamp  \
# 3196942   14    17      14       8        5          257 2019-09-14 17:14:08
# 2798983   12    12      54      18        1          285 2021-10-12 12:54:18
# 1013585   19     3      18      31        2           50 2020-02-19 03:18:31
# 2980283    3     4      11      27        3          338 2020-12-03 04:11:27
# 1920204   17     1      53      24        5          230 2024-08-17 01:53:24
# ...      ...   ...     ...     ...      ...          ...                 ...
# 5467102    9    16      42      41        2           99 2025-04-09 16:42:41
# 323336     4    17      18       1        4          155 2021-06-04 17:18:01
# 768108    19    17      43      10        2           50 2020-02-19 17:43:10
# 2310367    7    10      18      22        6          341 2025-12-07 10:18:22
# 2976245   21    15      30      31        1          264 2021-09-21 15:30:31
#
#          flag_rapid_txns  flag_high_risk_city
# 3196942                0                False
# 2798983                0                False
# 1013585                0                False
# 2980283                0                False
# 1920204                0                False
# ...                  ...                  ...
# 5467102                0                False
# 323336                 0                False
# 768108                 0                False
# 2310367                0                False
# 2976245                0                False
#
# [6362620 rows x 27 columns]

# %%
#Rule 3: High-risk region and odd time (e.g., 12 AM - 5 AM)

high_risk_states = [10, 12]  # Example state codes
df['flag_risky_time_region'] = ((df['State Source'].isin(high_risk_states)) & (df['hour'].between(0, 5)))

# %%
df
# Out:
#          Type     Amount  ID Source  Old Balance  New Balance  State Source  \
# 3196942     1  244486.46          0      8946.00         0.00             3
# 2798983     3    3170.28          1     58089.00     54918.72             3
# 1013585     3    8424.74          2       783.00         0.00             1
# 2980283     0  261877.19          3      7596.00    269473.19             1
# 1920204     0   20528.65          4   2302074.12   2322602.77             2
# ...       ...        ...        ...          ...          ...           ...
# 5467102     3   26585.43    6353302         0.00         0.00             6
# 323336      0   37516.21    6353303  18820782.28  18858298.49             5
# 768108      1  244962.21    6353304     22027.00         0.00             6
# 2310367     3   15714.59    6353305         0.00         0.00             6
# 2976245     1  275783.53    6353306    126018.02         0.00             3
#
#          City Source  Device Name             IMEI  KYC Status  ...  day  \
# 3196942           18            0  927866134346668           0  ...   14
# 2798983           18            0  523023208809408           2  ...   12
# 1013585           50            4  826769516434938           2  ...   19
# 2980283           37            3  808816955619213           1  ...    3
# 1920204           13            3   46281521129530           3  ...   17
# ...              ...          ...              ...         ...  ...  ...
# 5467102           30            1  358722602404200           0  ...    9
# 323336            25            4  955144871951531           3  ...    4
# 768108            30            1  270348759515170           3  ...   19
# 2310367           48            3  376257479668904           3  ...    7
# 2976245           18            0  710183950720366           2  ...   21
#
#          hour  minute  second  weekday  day_of_year           timestamp  \
# 3196942    17      14       8        5          257 2019-09-14 17:14:08
# 2798983    12      54      18        1          285 2021-10-12 12:54:18
# 1013585     3      18      31        2           50 2020-02-19 03:18:31
# 2980283     4      11      27        3          338 2020-12-03 04:11:27
# 1920204     1      53      24        5          230 2024-08-17 01:53:24
# ...       ...     ...     ...      ...          ...                 ...
# 5467102    16      42      41        2           99 2025-04-09 16:42:41
# 323336     17      18       1        4          155 2021-06-04 17:18:01
# 768108     17      43      10        2           50 2020-02-19 17:43:10
# 2310367    10      18      22        6          341 2025-12-07 10:18:22
# 2976245    15      30      31        1          264 2021-09-21 15:30:31
#
#          flag_rapid_txns  flag_high_risk_city  flag_risky_time_region
# 3196942                0                False                   False
# 2798983                0                False                   False
# 1013585                0                False                   False
# 2980283                0                False                   False
# 1920204                0                False                   False
# ...                  ...                  ...                     ...
# 5467102                0                False                   False
# 323336                 0                False                   False
# 768108                 0                False                   False
# 2310367                0                False                   False
# 2976245                0                False                   False
#
# [6362620 rows x 28 columns]

# %%
#Rule 4: Newly created receiving account and large amount
#Let’s assume accounts with IDs above a certain value (e.g., recent IDs > 10000) are new accounts.

amount_threshold = 100000  # Example threshold
df['flag_new_acc_large_amt'] = ((df['ID Dest'] > 10000) & (df['Amount'] > amount_threshold))

# %%
df
# Out:
#          Type     Amount  ID Source  Old Balance  New Balance  State Source  \
# 3196942     1  244486.46          0      8946.00         0.00             3
# 2798983     3    3170.28          1     58089.00     54918.72             3
# 1013585     3    8424.74          2       783.00         0.00             1
# 2980283     0  261877.19          3      7596.00    269473.19             1
# 1920204     0   20528.65          4   2302074.12   2322602.77             2
# ...       ...        ...        ...          ...          ...           ...
# 5467102     3   26585.43    6353302         0.00         0.00             6
# 323336      0   37516.21    6353303  18820782.28  18858298.49             5
# 768108      1  244962.21    6353304     22027.00         0.00             6
# 2310367     3   15714.59    6353305         0.00         0.00             6
# 2976245     1  275783.53    6353306    126018.02         0.00             3
#
#          City Source  Device Name             IMEI  KYC Status  ...  hour  \
# 3196942           18            0  927866134346668           0  ...    17
# 2798983           18            0  523023208809408           2  ...    12
# 1013585           50            4  826769516434938           2  ...     3
# 2980283           37            3  808816955619213           1  ...     4
# 1920204           13            3   46281521129530           3  ...     1
# ...              ...          ...              ...         ...  ...   ...
# 5467102           30            1  358722602404200           0  ...    16
# 323336            25            4  955144871951531           3  ...    17
# 768108            30            1  270348759515170           3  ...    17
# 2310367           48            3  376257479668904           3  ...    10
# 2976245           18            0  710183950720366           2  ...    15
#
#          minute  second  weekday  day_of_year           timestamp  \
# 3196942      14       8        5          257 2019-09-14 17:14:08
# 2798983      54      18        1          285 2021-10-12 12:54:18
# 1013585      18      31        2           50 2020-02-19 03:18:31
# 2980283      11      27        3          338 2020-12-03 04:11:27
# 1920204      53      24        5          230 2024-08-17 01:53:24
# ...         ...     ...      ...          ...                 ...
# 5467102      42      41        2           99 2025-04-09 16:42:41
# 323336       18       1        4          155 2021-06-04 17:18:01
# 768108       43      10        2           50 2020-02-19 17:43:10
# 2310367      18      22        6          341 2025-12-07 10:18:22
# 2976245      30      31        1          264 2021-09-21 15:30:31
#
#          flag_rapid_txns  flag_high_risk_city  flag_risky_time_region  \
# 3196942                0                False                   False
# 2798983                0                False                   False
# 1013585                0                False                   False
# 2980283                0                False                   False
# 1920204                0                False                   False
# ...                  ...                  ...                     ...
# 5467102                0                False                   False
# 323336                 0                False                   False
# 768108                 0                False                   False
# 2310367                0                False                   False
# 2976245                0                False                   False
#
#          flag_new_acc_large_amt
# 3196942                    True
# 2798983                   False
# 1013585                   False
# 2980283                    True
# 1920204                   False
# ...                         ...
# 5467102                   False
# 323336                    False
# 768108                     True
# 2310367                   False
# 2976245                    True
#
# [6362620 rows x 29 columns]

# %%
#Rule 5: Amount > mean + 3 * std for the user


user_stats = df.groupby('ID Source')['Amount'].agg(['mean', 'std']).reset_index()
df = df.merge(user_stats, on='ID Source', how='left')
df['flag_high_amount'] = df['Amount'] > (df['mean'] + 3 * df['std'])

# %%
df
# Out:
#          Type     Amount  ID Source  Old Balance  New Balance  State Source  \
# 0           1  244486.46          0      8946.00         0.00             3
# 1           3    3170.28          1     58089.00     54918.72             3
# 2           3    8424.74          2       783.00         0.00             1
# 3           0  261877.19          3      7596.00    269473.19             1
# 4           0   20528.65          4   2302074.12   2322602.77             2
# ...       ...        ...        ...          ...          ...           ...
# 6362615     3   26585.43    6353302         0.00         0.00             6
# 6362616     0   37516.21    6353303  18820782.28  18858298.49             5
# 6362617     1  244962.21    6353304     22027.00         0.00             6
# 6362618     3   15714.59    6353305         0.00         0.00             6
# 6362619     1  275783.53    6353306    126018.02         0.00             3
#
#          City Source  Device Name             IMEI  KYC Status  ...  weekday  \
# 0                 18            0  927866134346668           0  ...        5
# 1                 18            0  523023208809408           2  ...        1
# 2                 50            4  826769516434938           2  ...        2
# 3                 37            3  808816955619213           1  ...        3
# 4                 13            3   46281521129530           3  ...        5
# ...              ...          ...              ...         ...  ...      ...
# 6362615           30            1  358722602404200           0  ...        2
# 6362616           25            4  955144871951531           3  ...        4
# 6362617           30            1  270348759515170           3  ...        2
# 6362618           48            3  376257479668904           3  ...        6
# 6362619           18            0  710183950720366           2  ...        1
#
#          day_of_year           timestamp  flag_rapid_txns  \
# 0                257 2019-09-14 17:14:08                0
# 1                285 2021-10-12 12:54:18                0
# 2                 50 2020-02-19 03:18:31                0
# 3                338 2020-12-03 04:11:27                0
# 4                230 2024-08-17 01:53:24                0
# ...              ...                 ...              ...
# 6362615           99 2025-04-09 16:42:41                0
# 6362616          155 2021-06-04 17:18:01                0
# 6362617           50 2020-02-19 17:43:10                0
# 6362618          341 2025-12-07 10:18:22                0
# 6362619          264 2021-09-21 15:30:31                0
#
#          flag_high_risk_city  flag_risky_time_region  flag_new_acc_large_amt  \
# 0                      False                   False                    True
# 1                      False                   False                   False
# 2                      False                   False                   False
# 3                      False                   False                    True
# 4                      False                   False                   False
# ...                      ...                     ...                     ...
# 6362615                False                   False                   False
# 6362616                False                   False                   False
# 6362617                False                   False                    True
# 6362618                False                   False                   False
# 6362619                False                   False                    True
#
#               mean  std  flag_high_amount
# 0        244486.46  NaN             False
# 1          3170.28  NaN             False
# 2          8424.74  NaN             False
# 3        261877.19  NaN             False
# 4         20528.65  NaN             False
# ...            ...  ...               ...
# 6362615   26585.43  NaN             False
# 6362616   37516.21  NaN             False
# 6362617  244962.21  NaN             False
# 6362618   15714.59  NaN             False
# 6362619  275783.53  NaN             False
#
# [6362620 rows x 32 columns]

# %%
# Rule 6: Time outside user's 99% activity window
# Calculate the 0.5th and 99.5th percentile activity hour range per user

# Efficient quantile calculation using groupby and unstack
quantiles = df.groupby('ID Source')['hour'].quantile([0.005, 0.995]).unstack()
quantiles.columns = ['lower_bound', 'upper_bound']

# Merge the quantiles back to the original dataframe
df = df.merge(quantiles, left_on='ID Source', right_index=True)

# Flag if 'hour' is outside the user's 99% activity range
df['flag_time_outlier'] = ~df['hour'].between(df['lower_bound'], df['upper_bound'])

# %%
df
# Out:
#          Type     Amount  ID Source  Old Balance  New Balance  State Source  \
# 0           1  244486.46          0      8946.00         0.00             3
# 1           3    3170.28          1     58089.00     54918.72             3
# 2           3    8424.74          2       783.00         0.00             1
# 3           0  261877.19          3      7596.00    269473.19             1
# 4           0   20528.65          4   2302074.12   2322602.77             2
# ...       ...        ...        ...          ...          ...           ...
# 6362615     3   26585.43    6353302         0.00         0.00             6
# 6362616     0   37516.21    6353303  18820782.28  18858298.49             5
# 6362617     1  244962.21    6353304     22027.00         0.00             6
# 6362618     3   15714.59    6353305         0.00         0.00             6
# 6362619     1  275783.53    6353306    126018.02         0.00             3
#
#          City Source  Device Name             IMEI  KYC Status  ...  \
# 0                 18            0  927866134346668           0  ...
# 1                 18            0  523023208809408           2  ...
# 2                 50            4  826769516434938           2  ...
# 3                 37            3  808816955619213           1  ...
# 4                 13            3   46281521129530           3  ...
# ...              ...          ...              ...         ...  ...
# 6362615           30            1  358722602404200           0  ...
# 6362616           25            4  955144871951531           3  ...
# 6362617           30            1  270348759515170           3  ...
# 6362618           48            3  376257479668904           3  ...
# 6362619           18            0  710183950720366           2  ...
#
#          flag_rapid_txns  flag_high_risk_city  flag_risky_time_region  \
# 0                      0                False                   False
# 1                      0                False                   False
# 2                      0                False                   False
# 3                      0                False                   False
# 4                      0                False                   False
# ...                  ...                  ...                     ...
# 6362615                0                False                   False
# 6362616                0                False                   False
# 6362617                0                False                   False
# 6362618                0                False                   False
# 6362619                0                False                   False
#
#          flag_new_acc_large_amt       mean  std  flag_high_amount  \
# 0                          True  244486.46  NaN             False
# 1                         False    3170.28  NaN             False
# 2                         False    8424.74  NaN             False
# 3                          True  261877.19  NaN             False
# 4                         False   20528.65  NaN             False
# ...                         ...        ...  ...               ...
# 6362615                   False   26585.43  NaN             False
# 6362616                   False   37516.21  NaN             False
# 6362617                    True  244962.21  NaN             False
# 6362618                   False   15714.59  NaN             False
# 6362619                    True  275783.53  NaN             False
#
#          lower_bound  upper_bound  flag_time_outlier
# 0               17.0         17.0              False
# 1               12.0         12.0              False
# 2                3.0          3.0              False
# 3                4.0          4.0              False
# 4                1.0          1.0              False
# ...              ...          ...                ...
# 6362615         16.0         16.0              False
# 6362616         17.0         17.0              False
# 6362617         17.0         17.0              False
# 6362618         10.0         10.0              False
# 6362619         15.0         15.0              False
#
# [6362620 rows x 35 columns]

# %%
# ---------------------------------------------
# Rule 7: Flag Based on Sudden Distant Activity
# ---------------------------------------------
# 🚩 Rule 7:
# Flag a transaction if:
# - The distance between the user's last two transactions exceeds a defined threshold
# - AND the time difference between those transactions is less than `m` minutes

# ✅ What We Need:
# - Latitude and longitude of each transaction (currently not in dataset)
# - OR city codes mapped to coordinates (can simulate with a dictionary)
# - Timestamp for each transaction (can create from 'year', 'month', 'day', 'hour', 'minute', 'second' columns)

# 🎯 Thresholds (to define):
# - `MAX_DISTANCE_KM`: Maximum allowed distance between two transactions
# - `MIN_TIME_MINUTES`: Minimum allowed time between two transactions

# 🧠 Since We Don't Have lat/lon Right Now:
# - We can simulate distances based on city codes or names
# - OR skip the distance check and only apply time-based session logic

# 🧪 Simulated Strategy:
# - Use a city-to-coordinates dictionary (`city_coords`) if available
# - Calculate distance between coordinates (using haversine formula)
# - Calculate time difference between transactions
# - Flag if: distance > MAX_DISTANCE_KM and time_diff < MIN_TIME_MINUTES

# 🔧 You can later plug in actual lat/lon data (from city mappings or external sources) if needed

# Example coordinates (for simulation):
# city_coords = {
#     18: (31.5497, 74.3436),   # Lahore
#     25: (33.6844, 73.0479),   # Islamabad
#     ...
# }

# 🧭 Final Step:
# Loop over transactions grouped by user (`ID Source`),
# calculate distance and time difference between consecutive transactions,
# and flag those that break the rule as `flag_distance_time = True`

# Note: For now, we implemented this logic using simulated data and just the time-based condition
# You can enhance it further once you integrate lat/lon or city-level coordinates.

# %%
city_coords = {
    'Lahore': (31.5497, 74.3436),
    'Karachi': (24.8607, 67.0011),
    'Islamabad': (33.6844, 73.0479),
    'Peshawar': (34.0151, 71.5249),
    'Quetta': (30.1798, 66.9750),
    'Multan': (30.1575, 71.5249),
    'Faisalabad': (31.4504, 73.1350),
    'Rawalpindi': (33.5651, 73.0169),
    'Hyderabad': (25.3960, 68.3578),
    'Sukkur': (27.7052, 68.8574),
    # Add remaining cities...
}

# %%
pip install geopy
# Out:
# Collecting geopy
#   Downloading geopy-2.4.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting geographiclib<3,>=1.52 (from geopy)
#   Downloading geographiclib-2.0-py3-none-any.whl.metadata (1.4 kB)
# Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.4/125.4 kB 592.7 kB/s eta 0:00:00a 0:00:01
# Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 2.2 MB/s eta 0:00:00
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-2.0 geopy-2.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from geopy.distance import geodesic

# Assuming 'df' is your DataFrame and 'city_coords' is the dictionary from above

# Create a timestamp column if not already present
df['timestamp'] = pd.to_datetime(df[['year', 'month', 'day', 'hour', 'minute', 'second']])

# Sort the DataFrame by user and timestamp
df.sort_values(by=['ID Source', 'timestamp'], inplace=True)

# Initialize a column for the flag
df['flag_distance_time'] = False

# Define thresholds
DIST_THRESHOLD = 200  # in kilometers
TIME_THRESHOLD = 10   # in minutes

# Group by user
for user_id, group in df.groupby('ID Source'):
    group = group.reset_index()
    for i in range(1, len(group)):
        prev_city = group.loc[i - 1, 'City Source']
        curr_city = group.loc[i, 'City Source']
        prev_time = group.loc[i - 1, 'timestamp']
        curr_time = group.loc[i, 'timestamp']

        # Get coordinates
        prev_coords = city_coords.get(prev_city)
        curr_coords = city_coords.get(curr_city)

        # Proceed if both cities have coordinates
        if prev_coords and curr_coords:
            distance = geodesic(prev_coords, curr_coords).kilometers
            time_diff = (curr_time - prev_time).total_seconds() / 60.0  # in minutes

            if distance > DIST_THRESHOLD and time_diff < TIME_THRESHOLD:
                df.at[group.loc[i, 'index'], 'flag_distance_time'] = True

# %%
df
# Out:
#          Type     Amount  ID Source  Old Balance  New Balance  State Source  \
# 0           1  244486.46          0      8946.00         0.00             3
# 1           3    3170.28          1     58089.00     54918.72             3
# 2           3    8424.74          2       783.00         0.00             1
# 3           0  261877.19          3      7596.00    269473.19             1
# 4           0   20528.65          4   2302074.12   2322602.77             2
# ...       ...        ...        ...          ...          ...           ...
# 6362615     3   26585.43    6353302         0.00         0.00             6
# 6362616     0   37516.21    6353303  18820782.28  18858298.49             5
# 6362617     1  244962.21    6353304     22027.00         0.00             6
# 6362618     3   15714.59    6353305         0.00         0.00             6
# 6362619     1  275783.53    6353306    126018.02         0.00             3
#
#          City Source  Device Name             IMEI  KYC Status  ...  \
# 0                 18            0  927866134346668           0  ...
# 1                 18            0  523023208809408           2  ...
# 2                 50            4  826769516434938           2  ...
# 3                 37            3  808816955619213           1  ...
# 4                 13            3   46281521129530           3  ...
# ...              ...          ...              ...         ...  ...
# 6362615           30            1  358722602404200           0  ...
# 6362616           25            4  955144871951531           3  ...
# 6362617           30            1  270348759515170           3  ...
# 6362618           48            3  376257479668904           3  ...
# 6362619           18            0  710183950720366           2  ...
#
#          flag_high_risk_city  flag_risky_time_region  flag_new_acc_large_amt  \
# 0                      False                   False                    True
# 1                      False                   False                   False
# 2                      False                   False                   False
# 3                      False                   False                    True
# 4                      False                   False                   False
# ...                      ...                     ...                     ...
# 6362615                False                   False                   False
# 6362616                False                   False                   False
# 6362617                False                   False                    True
# 6362618                False                   False                   False
# 6362619                False                   False                    True
#
#               mean  std  flag_high_amount  lower_bound  upper_bound  \
# 0        244486.46  NaN             False         17.0         17.0
# 1          3170.28  NaN             False         12.0         12.0
# 2          8424.74  NaN             False          3.0          3.0
# 3        261877.19  NaN             False          4.0          4.0
# 4         20528.65  NaN             False          1.0          1.0
# ...            ...  ...               ...          ...          ...
# 6362615   26585.43  NaN             False         16.0         16.0
# 6362616   37516.21  NaN             False         17.0         17.0
# 6362617  244962.21  NaN             False         17.0         17.0
# 6362618   15714.59  NaN             False         10.0         10.0
# 6362619  275783.53  NaN             False         15.0         15.0
#
#          flag_time_outlier  flag_distance_time
# 0                    False               False
# 1                    False               False
# 2                    False               False
# 3                    False               False
# 4                    False               False
# ...                    ...                 ...
# 6362615              False               False
# 6362616              False               False
# 6362617              False               False
# 6362618              False               False
# 6362619              False               False
#
# [6362620 rows x 36 columns]

# %%
#Rule 8: Transactions per session vs. user median
#Approximate sessions by grouping transactions less than 15 mins apart.

df['prev_time'] = df.groupby('ID Source')['timestamp'].shift()
df['time_diff'] = (df['timestamp'] - df['prev_time']).dt.total_seconds() / 60.0
df['new_session'] = (df['time_diff'] > 15) | (df['time_diff'].isna())
df['session_id'] = df.groupby('ID Source')['new_session'].cumsum()

session_counts = df.groupby(['ID Source', 'session_id']).size().reset_index(name='session_txn_count')
median_txn_per_session = session_counts.groupby('ID Source')['session_txn_count'].median().reset_index(name='median_count')

df = df.merge(session_counts, on=['ID Source', 'session_id'])
df = df.merge(median_txn_per_session, on='ID Source')
df['flag_heavy_session'] = df['session_txn_count'] > df['median_count']

# %%
df
# Out:
#          Type     Amount  ID Source  Old Balance  New Balance  State Source  \
# 0           1  244486.46          0      8946.00         0.00             3
# 1           3    3170.28          1     58089.00     54918.72             3
# 2           3    8424.74          2       783.00         0.00             1
# 3           0  261877.19          3      7596.00    269473.19             1
# 4           0   20528.65          4   2302074.12   2322602.77             2
# ...       ...        ...        ...          ...          ...           ...
# 6362615     3   26585.43    6353302         0.00         0.00             6
# 6362616     0   37516.21    6353303  18820782.28  18858298.49             5
# 6362617     1  244962.21    6353304     22027.00         0.00             6
# 6362618     3   15714.59    6353305         0.00         0.00             6
# 6362619     1  275783.53    6353306    126018.02         0.00             3
#
#          City Source  Device Name             IMEI  KYC Status  ...  \
# 0                 18            0  927866134346668           0  ...
# 1                 18            0  523023208809408           2  ...
# 2                 50            4  826769516434938           2  ...
# 3                 37            3  808816955619213           1  ...
# 4                 13            3   46281521129530           3  ...
# ...              ...          ...              ...         ...  ...
# 6362615           30            1  358722602404200           0  ...
# 6362616           25            4  955144871951531           3  ...
# 6362617           30            1  270348759515170           3  ...
# 6362618           48            3  376257479668904           3  ...
# 6362619           18            0  710183950720366           2  ...
#
#          upper_bound  flag_time_outlier  flag_distance_time  prev_time  \
# 0               17.0              False               False        NaT
# 1               12.0              False               False        NaT
# 2                3.0              False               False        NaT
# 3                4.0              False               False        NaT
# 4                1.0              False               False        NaT
# ...              ...                ...                 ...        ...
# 6362615         16.0              False               False        NaT
# 6362616         17.0              False               False        NaT
# 6362617         17.0              False               False        NaT
# 6362618         10.0              False               False        NaT
# 6362619         15.0              False               False        NaT
#
#          time_diff  new_session  session_id  session_txn_count  median_count  \
# 0              NaN         True           1                  1           1.0
# 1              NaN         True           1                  1           1.0
# 2              NaN         True           1                  1           1.0
# 3              NaN         True           1                  1           1.0
# 4              NaN         True           1                  1           1.0
# ...            ...          ...         ...                ...           ...
# 6362615        NaN         True           1                  1           1.0
# 6362616        NaN         True           1                  1           1.0
# 6362617        NaN         True           1                  1           1.0
# 6362618        NaN         True           1                  1           1.0
# 6362619        NaN         True           1                  1           1.0
#
#          flag_heavy_session
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
# ...                     ...
# 6362615               False
# 6362616               False
# 6362617               False
# 6362618               False
# 6362619               False
#
# [6362620 rows x 43 columns]

# %%
#Final Step: Combine all flags
flag_cols = [col for col in df.columns if col.startswith('flag_')]
df['fraud_flag_combined'] = df[flag_cols].any(axis=1).astype(int)

print(f"Total flagged transactions: {df['fraud_flag_combined'].sum()}")
# Out:
# Total flagged transactions: 2797361

# %%
df[flag_cols].sum().sort_values(ascending=False)
# Out:
# flag_new_acc_large_amt    2787291
# flag_time_outlier           17812
# flag_high_risk_city             0
# flag_rapid_txns                 0
# flag_risky_time_region          0
# flag_high_amount                0
# flag_distance_time              0
# flag_heavy_session              0
# dtype: int64

# %%
df['flag_sum'] = df[flag_cols].sum(axis=1)
df['flag_sum'].value_counts()
# Out:
# flag_sum
# 0    3565259
# 1    2789619
# 2       7742
# Name: count, dtype: int64

# %%
df[df['fraud_flag_combined'] == 1].to_csv('flagged_transactions.csv', index=False)

# %%
df
# Out:
#          Type     Amount  ID Source  Old Balance  New Balance  State Source  \
# 0           1  244486.46          0      8946.00         0.00             3
# 1           3    3170.28          1     58089.00     54918.72             3
# 2           3    8424.74          2       783.00         0.00             1
# 3           0  261877.19          3      7596.00    269473.19             1
# 4           0   20528.65          4   2302074.12   2322602.77             2
# ...       ...        ...        ...          ...          ...           ...
# 6362615     3   26585.43    6353302         0.00         0.00             6
# 6362616     0   37516.21    6353303  18820782.28  18858298.49             5
# 6362617     1  244962.21    6353304     22027.00         0.00             6
# 6362618     3   15714.59    6353305         0.00         0.00             6
# 6362619     1  275783.53    6353306    126018.02         0.00             3
#
#          City Source  Device Name             IMEI  KYC Status  ...  \
# 0                 18            0  927866134346668           0  ...
# 1                 18            0  523023208809408           2  ...
# 2                 50            4  826769516434938           2  ...
# 3                 37            3  808816955619213           1  ...
# 4                 13            3   46281521129530           3  ...
# ...              ...          ...              ...         ...  ...
# 6362615           30            1  358722602404200           0  ...
# 6362616           25            4  955144871951531           3  ...
# 6362617           30            1  270348759515170           3  ...
# 6362618           48            3  376257479668904           3  ...
# 6362619           18            0  710183950720366           2  ...
#
#          flag_distance_time  prev_time  time_diff  new_session  session_id  \
# 0                     False        NaT        NaN         True           1
# 1                     False        NaT        NaN         True           1
# 2                     False        NaT        NaN         True           1
# 3                     False        NaT        NaN         True           1
# 4                     False        NaT        NaN         True           1
# ...                     ...        ...        ...          ...         ...
# 6362615               False        NaT        NaN         True           1
# 6362616               False        NaT        NaN         True           1
# 6362617               False        NaT        NaN         True           1
# 6362618               False        NaT        NaN         True           1
# 6362619               False        NaT        NaN         True           1
#
#          session_txn_count  median_count  flag_heavy_session  \
# 0                        1           1.0               False
# 1                        1           1.0               False
# 2                        1           1.0               False
# 3                        1           1.0               False
# 4                        1           1.0               False
# ...                    ...           ...                 ...
# 6362615                  1           1.0               False
# 6362616                  1           1.0               False
# 6362617                  1           1.0               False
# 6362618                  1           1.0               False
# 6362619                  1           1.0               False
#
#          fraud_flag_combined  flag_sum
# 0                          1         1
# 1                          0         0
# 2                          0         0
# 3                          1         1
# 4                          0         0
# ...                      ...       ...
# 6362615                    0         0
# 6362616                    0         0
# 6362617                    1         1
# 6362618                    0         0
# 6362619                    1         1
#
# [6362620 rows x 45 columns]
